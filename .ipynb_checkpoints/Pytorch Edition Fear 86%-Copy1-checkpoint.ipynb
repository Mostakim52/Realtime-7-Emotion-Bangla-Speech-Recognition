# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio

import torch
import torchaudio
from torch.utils.data import DataLoader, Dataset

import IPython.display as ipd

import torch.nn as nn
import torch.optim as optim
import torchaudio.transforms as transforms

# %%
# Check if GPU is available
print("Is GPU available? ", torch.cuda.is_available())

# Print GPU name
if torch.cuda.is_available():
    print("GPU: ", torch.cuda.get_device_name(0))
# Out:
# Is GPU available?  True
# GPU:  NVIDIA GeForce RTX 3070

# %% [markdown]
# # Exact Dataset Path

# %%
#from google.colab import drive
#drive.mount('/content/drive/')

# Replace with your actual dataset folder path
# Load the first dataset
dataset_path = r'C:\Users\Jim\Jupiter Projects\CSE499\B-SER dataset'
mendeley_dataset_path = r"C:\Users\Jim\Jupiter Projects\CSE499\KUET Bangla Emotional Speech (KBES) Dataset"  # Replace with the actual path
fear_dataset_path = r"C:\Users\Jim\Jupiter Projects\CSE499\North South Bangla Emotional Speech\Fear"
# Output path for reduced audio files
reduced_audio_path = r"D:\Study\2025 Fall\CSE499\Project Dataset\Noise Reduced Data"  # Replace with your desired output path
augmented_audio_path = r"D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data"

# %% [markdown]
# # KUET and BANGLASER mixing

# %%
import os
import librosa
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import StratifiedShuffleSplit
import seaborn as sns
import matplotlib.pyplot as plt
import noisereduce as nr
import soundfile as sf
from collections import Counter

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Paths
dataset_path = r"C:\Users\Jim\Jupiter Projects\CSE499\B-SER dataset"
mendeley_dataset_path = r"C:\Users\Jim\Jupiter Projects\CSE499\KUET Bangla Emotional Speech (KBES) Dataset"
fear_dataset_path = r"C:\Users\Jim\Jupiter Projects\CSE499\North South Bangla Emotional Speech\Fear"
reduced_audio_path = r"D:\Study\2025 Fall\CSE499\Project Dataset\Noise Reduced Data"
augmented_audio_path = r"D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data"

# Data Preprocessing
def standardize_audio(file_path, target_length=3, sample_rate=16000):
    try:
        waveform, sr = librosa.load(file_path, sr=sample_rate)
        target_samples = int(target_length * sample_rate)
        if len(waveform) < target_samples:
            waveform = np.pad(waveform, (0, target_samples - len(waveform)), mode='constant')
        else:
            waveform = waveform[:target_samples]
        return waveform, sr
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        raise

def augment_audio(waveform, sr, output_path, aug_type, idx):
    try:
        if aug_type == "pitch":
            augmented = librosa.effects.pitch_shift(y=waveform, sr=sr, n_steps=2)
            file_name = f"pitch_shifted_{idx}.wav"
        elif aug_type == "stretch":
            augmented = librosa.effects.time_stretch(y=waveform, rate=1.1)
            file_name = f"time_stretched_{idx}.wav"
        elif aug_type == "pitch2":
            augmented = librosa.effects.pitch_shift(y=waveform, sr=sr, n_steps=-2)
            file_name = f"pitch_shifted_neg_{idx}.wav"
        aug_path = os.path.join(output_path, file_name)
        print(f"Attempting to write: {aug_path}")
        sf.write(aug_path, augmented, sr)
        if not os.path.exists(aug_path):
            raise Exception(f"Failed to write {aug_path}")
        print(f"  Successfully created: {aug_path}")
        return aug_path
    except Exception as e:
        print(f"Error in augment_audio for {aug_type}_{idx}: {e}")
        raise

def reduce_noise(waveform, sr, output_path):
    try:
        reduced = nr.reduce_noise(y=waveform, sr=sr)
        sf.write(output_path, reduced, sr)
        if not os.path.exists(output_path):
            raise Exception(f"Failed to write {output_path}")
        return output_path
    except Exception as e:
        print(f"Error in reduce_noise for {output_path}: {e}")
        raise

def load_bser_dataset(dataset_path, target_length=3):
    paths, labels = [], []
    label_mapping = {"01": "happy", "02": "sad", "03": "angry", "04": "surprise", "05": "neutral"}
    for actor in range(1, 35):
        actor_path = os.path.join(dataset_path, f"Actor {actor:02d}")
        if not os.path.isdir(actor_path):
            print(f"Skipping {actor_path}: not a directory")
            continue
        for file in os.listdir(actor_path):
            if file.endswith(".wav"):
                parts = file.split("-")
                if len(parts) < 3 or parts[2] not in label_mapping:
                    continue
                file_path = os.path.join(actor_path, file)
                paths.append(file_path)
                labels.append(label_mapping[parts[2]])
    print(f"B-SER: {len(paths)} files loaded")
    return paths, labels

def load_kbes_dataset(dataset_path, target_length=3):
    paths, labels = [], []
    label_mapping = {
        "Angry (High)": "angry", "Angry (Low)": "angry",
        "Happy (High)": "happy", "Happy (Low)": "happy",
        "Neutral": "neutral",
        "Sad (High)": "sad", "Sad (Low)": "sad",
        "Disgust": "disgust", "Disgust (High)": "disgust", "Disgust (Low)": "disgust"
    }
    for emotion_folder in os.listdir(dataset_path):
        emotion_path = os.path.join(dataset_path, emotion_folder)
        if not os.path.isdir(emotion_path):
            continue
        if emotion_folder not in label_mapping:
            print(f"Skipping unknown folder: {emotion_folder}")
            continue
        num_files = len([f for f in os.listdir(emotion_path) if f.endswith(".wav")])
        print(f"{emotion_folder}: {num_files} files")
        for file in os.listdir(emotion_path):
            if file.endswith(".wav"):
                file_path = os.path.join(emotion_path, file)
                paths.append(file_path)
                labels.append(label_mapping[emotion_folder])
    print(f"KBES: {len(paths)} files loaded")
    return paths, labels

def load_fear_dataset(dataset_path, target_length=3):
    paths, labels = [], []
    for file in os.listdir(dataset_path):
        if file.endswith(".wav"):
            file_path = os.path.join(dataset_path, file)
            paths.append(file_path)
            labels.append("fear")
    print(f"Fear: {len(paths)} files loaded")
    return paths, labels

def augment_to_target(paths, labels, target_count=506, augmented_base_path=augmented_audio_path):
    print("Starting augmentation...")
    label_counts = Counter(labels)
    all_paths, all_labels = paths.copy(), labels.copy()  # Start with original files
    
    for label in label_counts:
        original_count = label_counts[label]
        print(f"Label {label}: {original_count} original samples")
        label_dir = os.path.join(augmented_base_path, label)
        os.makedirs(label_dir, exist_ok=True)
        print(f"  Directory: {label_dir}")
        
        # Get original paths for this label
        label_paths = [p for p, l in zip(paths, labels) if l == label]
        
        # Count existing augmented files in the label directory
        existing_aug_files = [f for f in os.listdir(label_dir) if f.endswith(".wav")]
        existing_aug_count = len(existing_aug_files)
        print(f"  Found {existing_aug_count} existing augmented files in {label_dir}")
        
        # Total files = original + existing augmented
        total_current = original_count + existing_aug_count
        print(f"  Total current files (original + augmented): {total_current}")
        
        if total_current >= target_count:
            print(f"  No augmentation needed for {label} (already has {total_current} files)")
            # Add existing augmented files to all_paths if not already included
            for file in existing_aug_files:
                file_path = os.path.join(label_dir, file)
                if file_path not in all_paths:
                    all_paths.append(file_path)
                    all_labels.append(label)
            continue
        
        needed = target_count - total_current
        print(f"  Need to generate {needed} additional augmented files for {label}")
        
        aug_types = ["pitch", "stretch", "pitch2"]
        aug_idx = existing_aug_count  # Start idx from existing augmented count
        
        while needed > 0:
            orig_idx = aug_idx // len(aug_types) % len(label_paths)
            aug_type_idx = aug_idx % len(aug_types)
            aug_type = aug_types[aug_type_idx]
            
            print(f"  Processing {label_paths[orig_idx]} with {aug_type} (aug_idx: {aug_idx})")
            waveform, sr = standardize_audio(label_paths[orig_idx])
            base_name = os.path.basename(label_paths[orig_idx]).replace(".wav", "")
            aug_path = os.path.join(label_dir, f"{base_name}_{aug_type}_{aug_idx}.wav")
            
            if not os.path.exists(aug_path):
                aug_path = augment_audio(waveform, sr, label_dir, aug_type, aug_idx)
            else:
                print(f"  Skipping existing file: {aug_path}")
            
            if aug_path not in all_paths:  # Avoid duplicates
                all_paths.append(aug_path)
                all_labels.append(label)
            needed -= 1
            aug_idx += 1
        
        print(f"  After augmentation, {label} has {original_count + existing_aug_count + (target_count - total_current)} samples")
    
    print(f"Total augmented samples: {len(all_paths)}")
    invalid_paths = [p for p in all_paths if not os.path.exists(p)]
    if invalid_paths:
        print(f"Warning: {len(invalid_paths)} paths do not exist: {invalid_paths[:5]}...")
    return all_paths, all_labels

def process_and_reduce_noise(paths, labels, reduced_base_path):
    reduced_paths, reduced_labels = [], []
    for path, label in zip(paths, labels):
        if not os.path.exists(path):
            print(f"Warning: {path} does not exist, skipping")
            continue
        label_dir = os.path.join(reduced_base_path, label)
        os.makedirs(label_dir, exist_ok=True)
        base_name = os.path.basename(path).replace(".wav", "_reduced.wav")
        reduced_file = os.path.join(label_dir, base_name)
        if not os.path.exists(reduced_file):
            waveform, sr = standardize_audio(path)
            reduce_noise(waveform, sr, reduced_file)
        reduced_paths.append(reduced_file)
        reduced_labels.append(label)
    print(f"Total reduced samples: {len(reduced_paths)}")
    return reduced_paths, reduced_labels

def extract_mfcc(file_path, sample_rate=16000, n_mfcc=40, n_frames=300):
    waveform, sr = librosa.load(file_path, sr=sample_rate)
    mfcc = librosa.feature.mfcc(y=waveform, sr=sr, n_mfcc=n_mfcc, hop_length=len(waveform)//(n_frames-1))
    if mfcc.shape[1] < n_frames:
        mfcc = np.pad(mfcc, ((0, 0), (0, n_frames - mfcc.shape[1])), mode='constant')
    else:
        mfcc = mfcc[:, :n_frames]
    return mfcc

def precompute_mfccs(paths, save_dir, sample_rate=16000, n_mfcc=40, n_frames=300):
    os.makedirs(save_dir, exist_ok=True)
    mfcc_paths = []
    for i, file_path in enumerate(paths):
        save_path = os.path.join(save_dir, f"mfcc_{i}.npy")
        if not os.path.exists(save_path):
            mfcc = extract_mfcc(file_path, sample_rate, n_mfcc, n_frames)
            np.save(save_path, mfcc)
        mfcc_paths.append(save_path)
    return mfcc_paths

class PrecomputedAudioDataset(Dataset):
    def __init__(self, mfcc_paths, labels, label_map):
        self.mfcc_paths = mfcc_paths
        self.labels = [label_map[l] for l in labels]

    def __len__(self):
        return len(self.mfcc_paths)

    def __getitem__(self, idx):
        mfcc = np.load(self.mfcc_paths[idx])
        return torch.tensor(mfcc, dtype=torch.float32), torch.tensor(self.labels[idx], dtype=torch.long)

# Model Definition
class CNNBackbone(nn.Module):
    def __init__(self):
        super(CNNBackbone, self).__init__()
        self.block1 = nn.Sequential(
            nn.Conv1d(40, 64, kernel_size=3, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=False)
        )
        self.pool1 = nn.MaxPool1d(2)
        self.block2 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU()
        )
        self.pool2 = nn.AdaptiveMaxPool1d(31)

    def forward(self, x):
        x = self.block1(x)
        x = self.pool1(x)
        x = self.block2(x)
        x = self.pool2(x)
        return x

class CNNTransformerHybrid(nn.Module):
    def __init__(self, num_classes=7):
        super(CNNTransformerHybrid, self).__init__()
        self.cnn = CNNBackbone()
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=64, nhead=4, dim_feedforward=256, dropout=0.1, batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)
        self.fc = nn.Linear(31 * 128, num_classes)

    def forward(self, x):
        cnn_out = self.cnn(x)
        transformer_in = cnn_out.permute(0, 2, 1)
        transformer_out = self.transformer(transformer_in)
        combined = torch.cat((cnn_out.permute(0, 2, 1), transformer_out), dim=-1)
        combined = combined.reshape(combined.size(0), -1)
        out = self.fc(combined)
        return out

# Training and Evaluation with Early Stopping
def train_model(model, train_loader, val_loader, num_epochs=500, patience=20):
    model = model.to(device)
    optimizer = Adam(model.parameters(), lr=1e-3)
    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=5)
    criterion = nn.CrossEntropyLoss().to(device)
    
    best_val_accuracy = -float('inf')
    best_model_state = None
    patience_counter = 0
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for i, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        # Validation phase
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(targets.cpu().numpy())
        
        val_accuracy = accuracy_score(all_labels, all_preds)
        avg_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
        
        # Learning rate scheduling
        scheduler.step(val_accuracy)
        
        # Early stopping logic
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            best_model_state = model.state_dict()
            patience_counter = 0
            print(f"  New best model saved with Val Accuracy: {best_val_accuracy:.4f}")
        else:
            patience_counter += 1
            print(f"  No improvement. Patience counter: {patience_counter}/{patience}")
        
        if patience_counter >= patience:
            print(f"Early stopping triggered after {epoch+1} epochs.")
            print(f"Restoring best model with Val Accuracy: {best_val_accuracy:.4f}")
            model.load_state_dict(best_model_state)
            break
    
    if patience_counter < patience:
        print(f"Training completed all {num_epochs} epochs.")
        print(f"Best Val Accuracy: {best_val_accuracy:.4f}")
    
    return model

def evaluate_model(model, test_loader, label_map):
    model = model.to(device)
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(targets.cpu().numpy())

    unique_labels = np.unique(all_labels)
    label_map_inv = {v: k for k, v in label_map.items()}
    present_classes = [label_map_inv[i] for i in unique_labels]

    print("Classes present in test set:", present_classes)
    print(classification_report(
        all_labels, 
        all_preds, 
        labels=unique_labels, 
        target_names=present_classes, 
        zero_division=0
    ))

    cm = confusion_matrix(all_labels, all_preds, labels=unique_labels)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=present_classes, yticklabels=present_classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    class_counts = np.bincount(all_labels, minlength=len(label_map))
    class_acc = [cm[i, i] / class_counts[unique_labels[i]] for i in range(len(unique_labels)) if class_counts[unique_labels[i]] > 0]
    weighted_acc = np.sum(class_acc * class_counts[unique_labels] / len(all_labels))
    print(f"Weighted Accuracy: {weighted_acc:.4f}")

# Main Execution
if __name__ == "__main__":
    # Load datasets
    bser_paths, bser_labels = load_bser_dataset(dataset_path)
    kbes_paths, kbes_labels = load_kbes_dataset(mendeley_dataset_path)
    fear_paths, fear_labels = load_fear_dataset(fear_dataset_path)

    # Combine original paths and labels
    all_paths = bser_paths + kbes_paths + fear_paths
    all_labels = bser_labels + kbes_labels + fear_labels
    print(f"Original samples: {len(all_paths)}")

    # Augment to 506 samples per class
    augmented_paths, augmented_labels = augment_to_target(all_paths, all_labels, target_count=506)

    # Reduce noise for all audios
    reduced_paths, reduced_labels = process_and_reduce_noise(augmented_paths, augmented_labels, reduced_audio_path)

    # Define label map with 7 classes
    label_map = {"neutral": 0, "happy": 1, "sad": 2, "angry": 3, "surprise": 4, "disgust": 5, "fear": 6}

    # Precompute MFCCs for reduced audios
    save_dir = r"D:\Study\2025 Fall\CSE499\Project Dataset\MFCC_cache"
    all_mfcc_paths = precompute_mfccs(reduced_paths, save_dir)
    dataset = PrecomputedAudioDataset(all_mfcc_paths, reduced_labels, label_map)
    print(f"Total samples: {len(dataset)}")

    # Stratified split
    numerical_labels = [label_map[label] for label in reduced_labels]
    print(f"Label distribution: {np.bincount(numerical_labels)}")

    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
    train_val_idx, test_idx = next(sss.split(all_mfcc_paths, numerical_labels))
    train_val_paths = [all_mfcc_paths[i] for i in train_val_idx]
    train_val_labels = [numerical_labels[i] for i in train_val_idx]

    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.125, random_state=42)
    train_idx, val_idx = next(sss.split(train_val_paths, train_val_labels))

    train_dataset = torch.utils.data.Subset(dataset, train_idx)
    val_dataset = torch.utils.data.Subset(dataset, val_idx)
    test_dataset = torch.utils.data.Subset(dataset, test_idx)

    print(f"Train samples: {len(train_dataset)}, Val samples: {len(val_dataset)}, Test samples: {len(test_dataset)}")
    test_labels = [dataset[i][1].item() for i in test_idx]
    print(f"Test set label distribution: {np.bincount(test_labels)}")

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=32, num_workers=0, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=32, num_workers=0, pin_memory=True)
    print(f"Train batches: {len(train_loader)}")

    torch.cuda.empty_cache()
    model = CNNTransformerHybrid(num_classes=7).to(device)
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Total parameters: {total_params}")
    print("Starting training...")
    model = train_model(model, train_loader, val_loader, num_epochs=500, patience=20)
    evaluate_model(model, test_loader, label_map)
# Out:
# Using device: cuda
# B-SER: 1467 files loaded
# Angry (High): 100 files
# Angry (Low): 100 files
# Disgust (High): 100 files
# Disgust (Low): 100 files
# Happy (High): 100 files
# Happy (Low): 100 files
# Neutral: 100 files
# Sad (High): 100 files
# Sad (Low): 100 files
# KBES: 900 files loaded
# Fear: 93 files loaded
# Original samples: 2460
# Starting augmentation...
# Label happy: 506 original samples
#   Directory: D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\happy
#   Found 0 existing augmented files in D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\happy
#   Total current files (original + augmented): 506
#   No augmentation needed for happy (already has 506 files)
# Label sad: 506 original samples
#   Directory: D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\sad
#   Found 0 existing augmented files in D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\sad
#   Total current files (original + augmented): 506
#   No augmentation needed for sad (already has 506 files)
# Label angry: 506 original samples
#   Directory: D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\angry
#   Found 0 existing augmented files in D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\angry
#   Total current files (original + augmented): 506
#   No augmentation needed for angry (already has 506 files)
# Label surprise: 306 original samples
#   Directory: D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\surprise
#   Found 200 existing augmented files in D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\surprise
#   Total current files (original + augmented): 506
#   No augmentation needed for surprise (already has 506 files)
# Label neutral: 343 original samples
#   Directory: D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\neutral
#   Found 163 existing augmented files in D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\neutral
#   Total current files (original + augmented): 506
#   No augmentation needed for neutral (already has 506 files)
# Label disgust: 200 original samples
#   Directory: D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\disgust
#   Found 306 existing augmented files in D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\disgust
#   Total current files (original + augmented): 506
#   No augmentation needed for disgust (already has 506 files)
# Label fear: 93 original samples
#   Directory: D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\fear
#   Found 413 existing augmented files in D:\Study\2025 Fall\CSE499\Project Dataset\Augmented Data\fear
#   Total current files (original + augmented): 506
#   No augmentation needed for fear (already has 506 files)
# Total augmented samples: 3542
# Total reduced samples: 3542
# Total samples: 3542
# Label distribution: [506 506 506 506 506 506 506]
# Train samples: 2478, Val samples: 355, Test samples: 709
# Test set label distribution: [101 101 101 102 101 101 102]
# Train batches: 78
# Total parameters: 148103
# Starting training...
# Epoch 1/500, Loss: 1.5913, Val Accuracy: 0.4789
#   New best model saved with Val Accuracy: 0.4789
# Epoch 2/500, Loss: 1.1485, Val Accuracy: 0.4732
#   No improvement. Patience counter: 1/20
# Epoch 3/500, Loss: 0.9294, Val Accuracy: 0.4563
#   No improvement. Patience counter: 2/20
# Epoch 4/500, Loss: 0.7923, Val Accuracy: 0.5239
#   New best model saved with Val Accuracy: 0.5239
# Epoch 5/500, Loss: 0.6241, Val Accuracy: 0.5662
#   New best model saved with Val Accuracy: 0.5662
# Epoch 6/500, Loss: 0.4988, Val Accuracy: 0.5099
#   No improvement. Patience counter: 1/20
# Epoch 7/500, Loss: 0.4016, Val Accuracy: 0.5155
#   No improvement. Patience counter: 2/20
# Epoch 8/500, Loss: 0.3649, Val Accuracy: 0.5099
#   No improvement. Patience counter: 3/20
# Epoch 9/500, Loss: 0.3608, Val Accuracy: 0.6113
#   New best model saved with Val Accuracy: 0.6113
# Epoch 10/500, Loss: 0.2740, Val Accuracy: 0.6028
#   No improvement. Patience counter: 1/20
# Epoch 11/500, Loss: 0.2288, Val Accuracy: 0.5803
#   No improvement. Patience counter: 2/20
# Epoch 12/500, Loss: 0.2050, Val Accuracy: 0.6197
#   New best model saved with Val Accuracy: 0.6197
# Epoch 13/500, Loss: 0.1924, Val Accuracy: 0.6169
#   No improvement. Patience counter: 1/20
# Epoch 14/500, Loss: 0.1530, Val Accuracy: 0.6000
#   No improvement. Patience counter: 2/20
# Epoch 15/500, Loss: 0.1322, Val Accuracy: 0.6423
#   New best model saved with Val Accuracy: 0.6423
# Epoch 16/500, Loss: 0.0967, Val Accuracy: 0.6225
#   No improvement. Patience counter: 1/20
# Epoch 17/500, Loss: 0.0806, Val Accuracy: 0.5380
#   No improvement. Patience counter: 2/20
# Epoch 18/500, Loss: 0.1226, Val Accuracy: 0.5859
#   No improvement. Patience counter: 3/20
# Epoch 19/500, Loss: 0.1232, Val Accuracy: 0.6479
#   New best model saved with Val Accuracy: 0.6479
# Epoch 20/500, Loss: 0.1074, Val Accuracy: 0.6479
#   No improvement. Patience counter: 1/20
# Epoch 21/500, Loss: 0.0921, Val Accuracy: 0.6394
#   No improvement. Patience counter: 2/20
# Epoch 22/500, Loss: 0.0581, Val Accuracy: 0.6056
#   No improvement. Patience counter: 3/20
# Epoch 23/500, Loss: 0.0859, Val Accuracy: 0.6141
#   No improvement. Patience counter: 4/20
# Epoch 24/500, Loss: 0.1104, Val Accuracy: 0.5972
#   No improvement. Patience counter: 5/20
# Epoch 25/500, Loss: 0.0913, Val Accuracy: 0.6592
#   New best model saved with Val Accuracy: 0.6592
# Epoch 26/500, Loss: 0.0698, Val Accuracy: 0.5915
#   No improvement. Patience counter: 1/20
# Epoch 27/500, Loss: 0.0756, Val Accuracy: 0.6169
#   No improvement. Patience counter: 2/20
# Epoch 28/500, Loss: 0.0928, Val Accuracy: 0.6254
#   No improvement. Patience counter: 3/20
# Epoch 29/500, Loss: 0.0746, Val Accuracy: 0.6563
#   No improvement. Patience counter: 4/20
# Epoch 30/500, Loss: 0.0801, Val Accuracy: 0.6113
#   No improvement. Patience counter: 5/20
# Epoch 31/500, Loss: 0.0567, Val Accuracy: 0.6732
#   New best model saved with Val Accuracy: 0.6732
# Epoch 32/500, Loss: 0.0485, Val Accuracy: 0.6873
#   New best model saved with Val Accuracy: 0.6873
# Epoch 33/500, Loss: 0.0871, Val Accuracy: 0.6845
#   No improvement. Patience counter: 1/20
# Epoch 34/500, Loss: 0.0744, Val Accuracy: 0.6338
#   No improvement. Patience counter: 2/20
# Epoch 35/500, Loss: 0.0820, Val Accuracy: 0.6394
#   No improvement. Patience counter: 3/20
# Epoch 36/500, Loss: 0.0706, Val Accuracy: 0.6225
#   No improvement. Patience counter: 4/20
# Epoch 37/500, Loss: 0.0851, Val Accuracy: 0.6366
#   No improvement. Patience counter: 5/20
# Epoch 38/500, Loss: 0.1034, Val Accuracy: 0.6000
#   No improvement. Patience counter: 6/20
# Epoch 39/500, Loss: 0.0636, Val Accuracy: 0.6535
#   No improvement. Patience counter: 7/20
# Epoch 40/500, Loss: 0.0286, Val Accuracy: 0.6732
#   No improvement. Patience counter: 8/20
# Epoch 41/500, Loss: 0.0167, Val Accuracy: 0.6704
#   No improvement. Patience counter: 9/20
# Epoch 42/500, Loss: 0.0157, Val Accuracy: 0.6704
#   No improvement. Patience counter: 10/20
# Epoch 43/500, Loss: 0.0140, Val Accuracy: 0.6817
#   No improvement. Patience counter: 11/20
# Epoch 44/500, Loss: 0.0100, Val Accuracy: 0.6901
#   New best model saved with Val Accuracy: 0.6901
# Epoch 45/500, Loss: 0.0094, Val Accuracy: 0.6845
#   No improvement. Patience counter: 1/20
# Epoch 46/500, Loss: 0.0112, Val Accuracy: 0.6817
#   No improvement. Patience counter: 2/20
# Epoch 47/500, Loss: 0.0071, Val Accuracy: 0.6704
#   No improvement. Patience counter: 3/20
# Epoch 48/500, Loss: 0.0102, Val Accuracy: 0.6817
#   No improvement. Patience counter: 4/20
# Epoch 49/500, Loss: 0.0067, Val Accuracy: 0.6873
#   No improvement. Patience counter: 5/20
# Epoch 50/500, Loss: 0.0058, Val Accuracy: 0.6873
#   No improvement. Patience counter: 6/20
# Epoch 51/500, Loss: 0.0050, Val Accuracy: 0.6789
#   No improvement. Patience counter: 7/20
# Epoch 52/500, Loss: 0.0066, Val Accuracy: 0.6817
#   No improvement. Patience counter: 8/20
# Epoch 53/500, Loss: 0.0066, Val Accuracy: 0.6901
#   No improvement. Patience counter: 9/20
# Epoch 54/500, Loss: 0.0057, Val Accuracy: 0.6789
#   No improvement. Patience counter: 10/20
# Epoch 55/500, Loss: 0.0062, Val Accuracy: 0.6789
#   No improvement. Patience counter: 11/20
# Epoch 56/500, Loss: 0.0115, Val Accuracy: 0.6676
#   No improvement. Patience counter: 12/20
# Epoch 57/500, Loss: 0.0049, Val Accuracy: 0.6817
#   No improvement. Patience counter: 13/20
# Epoch 58/500, Loss: 0.0042, Val Accuracy: 0.6732
#   No improvement. Patience counter: 14/20
# Epoch 59/500, Loss: 0.0061, Val Accuracy: 0.6789
#   No improvement. Patience counter: 15/20
# Epoch 60/500, Loss: 0.0050, Val Accuracy: 0.6817
#   No improvement. Patience counter: 16/20
# Epoch 61/500, Loss: 0.0056, Val Accuracy: 0.6817
#   No improvement. Patience counter: 17/20
# Epoch 62/500, Loss: 0.0043, Val Accuracy: 0.6817
#   No improvement. Patience counter: 18/20
# Epoch 63/500, Loss: 0.0086, Val Accuracy: 0.6761
#   No improvement. Patience counter: 19/20
# Epoch 64/500, Loss: 0.0058, Val Accuracy: 0.6761
#   No improvement. Patience counter: 20/20
# Early stopping triggered after 64 epochs.
# Restoring best model with Val Accuracy: 0.6901
# Classes present in test set: ['neutral', 'happy', 'sad', 'angry', 'surprise', 'disgust', 'fear']
#               precision    recall  f1-score   support
#
#      neutral       0.82      0.95      0.88       101
#        happy       0.79      0.93      0.85       101
#          sad       0.74      0.97      0.84       101
#        angry       0.87      0.95      0.91       102
#     surprise       0.98      0.92      0.95       101
#      disgust       0.93      0.64      0.76       101
#         fear       1.00      0.63      0.77       102
#
#     accuracy                           0.86       709
#    macro avg       0.88      0.86      0.85       709
# weighted avg       0.88      0.86      0.85       709
# Weighted Accuracy: 0.8561

# %%
def clear_memory():
    import gc
    import torch

    # Clear GPU memory (PyTorch)
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Clear RAM memory
    gc.collect()

# Call the function
clear_memory()
